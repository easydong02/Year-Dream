# %%
import numpy as np

# %%
def activation(z):
    return 1 / (1+np.exp(-z))

# %%
def AND(x,y):
    wx = 20
    wy = 20
    bias = -30

    if activation((wx*x + wy*y + bias)) < 0.5:  #bias는 1과 곱해질거라 그대로 변수 이용
        return 0
    else: 
        return 1

# %%
print(f"x=0, y=0: {AND(0,0)}")
print(f"x=0, y=1: {AND(0,1)}")
print(f"x=1, y=0: {AND(1,0)}")
print(f"x=1, y=1: {AND(1,1)}")
# Out:
# x=0, y=0: 0
# x=0, y=1: 0
# x=1, y=0: 0
# x=1, y=1: 1

# %%
def OR(x,y):
    # or 게이트로 작동하기위한 웨이트값 코딩 [+]
    wx = 20
    wy = 20
    bias = -10 # x,y 둘 중 하나라도 들어오면 전체 아웃풋이 양수가 되면 됨
    if activation((wx*x + wy*y + bias)) < 0.5: 
        return 0
    else: 
        return 1

# %%
print(f"x=0, y=0: {OR(0,0)}")
print(f"x=0, y=1: {OR(0,1)}")
print(f"x=1, y=0: {OR(1,0)}")
print(f"x=1, y=1: {OR(1,1)}")
# Out:
# x=0, y=0: 0
# x=0, y=1: 1
# x=1, y=0: 1
# x=1, y=1: 1

# %%
def NAND(x,y):
    wx = -20
    wy = -20
    bias = 30

    if activation((wx*x + wy*y + bias)) < 0.5: 
        return 0
    else: 
        return 1

# %%
print(f"x=0, y=0: {NAND(0,0)}")
print(f"x=0, y=1: {NAND(0,1)}")
print(f"x=1, y=0: {NAND(1,0)}")
print(f"x=1, y=1: {NAND(1,1)}")
# Out:
# x=0, y=0: 1
# x=0, y=1: 1
# x=1, y=0: 1
# x=1, y=1: 0

# %%
def NOR(x,y):
    wx = -20
    wy = -20
    bias = 10

    if activation((wx*x + wy*y + bias)) < 0.5: 
        return 0
    else: 
        return 1

# %%
print(f"x=0, y=0: {NOR(0,0)}")
print(f"x=0, y=1: {NOR(0,1)}")
print(f"x=1, y=0: {NOR(1,0)}")
print(f"x=1, y=1: {NOR(1,1)}")
# Out:
# x=0, y=0: 1
# x=0, y=1: 0
# x=1, y=0: 0
# x=1, y=1: 0

# %%
def XOR1(x, y):
    a = NOR(x,x)
    b = NOR(y,y)
    c = NOR(a,b)
    d = NOR(x,y)
    e = NOR(c,d)

    return e

# %%
print(f"x=0, y=0: {XOR1(0,0)}")
print(f"x=0, y=1: {XOR1(0,1)}")
print(f"x=1, y=0: {XOR1(1,0)}")
print(f"x=1, y=1: {XOR1(1,1)}")
# Out:
# x=0, y=0: 0
# x=0, y=1: 1
# x=1, y=0: 1
# x=1, y=1: 0

# %%
def XOR(x, y):
    ############################
    # WRITE CODE HERE 
    a = NAND(x,y)
    b = OR(x,y)
    c = AND(a,b)
    return c

# %%
print(f"x=0, y=0: {XOR(0,0)}")
print(f"x=0, y=1: {XOR(0,1)}")
print(f"x=1, y=0: {XOR(1,0)}")
print(f"x=1, y=1: {XOR(1,1)}")
# Out:
# x=0, y=0: 0
# x=0, y=1: 1
# x=1, y=0: 1
# x=1, y=1: 0
